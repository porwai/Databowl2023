# %%
import pandas as pd # for data manipulation
import numpy as np # for data manipulation

from sklearn.model_selection import train_test_split # for splitting the data into train and test samples
from sklearn.metrics import classification_report # for model evaluation metrics
from sklearn import tree # for decision tree models

import plotly.express as px  # for data visualization
import plotly.graph_objects as go # for data visualization
import graphviz # for plotting decision tree graphs

from sklearn.preprocessing import OneHotEncoder

from sklearn.preprocessing import MultiLabelBinarizer

# %%
# Set Pandas options to display more columns

# Read in the movie data csv
df=pd.read_csv('horror_movies_train.csv', encoding='utf-8')
df.drop(df.tail(1).index,inplace=True)

# Get one hot encoding of columns B
one_hot = pd.get_dummies(df['language'])
# Drop column B as it is now encoded
#df = df.drop('languauge',axis = 1)
# Join the encoded df
df = df.drop('language', axis=1)
df = df.join(one_hot, lsuffix="_left")


df['genres'] = df['genres'].str.replace(' ', '')
df['genres'] = df['genres'].str.strip().str.split(',')
s = df['genres'].explode()
df = df.join(pd.crosstab(s.index, s))

#df = df.drop('genres', axis=1)

#relevant_col = ['date_number', 'popularity', 'reviews', 'reviews_average', 'budget', 'runtime', 'af', 'ar', 'bn', 'cn', 'cs', 'cy', 'da', 'de', 'el', 'en', 'es', 'fa', 'fr', 'he', 'hi', 'hu', 'id', 'is', 'it', 'ja', 'km', 'kn', 'ko', 'mk', 'ml', 'mn', 'mr', 'ms', 'nb', 'nl', 'no', 'pl', 'pt', 'ru', 'sh', 'si', 'sk', 'sl', 'sr', 'sv', 'ta', 'te', 'th', 'tl', 'tr', 'uk', 'ur', 'xx', 'zh', 'Action', 'Adventure', 'Animation', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy', 'History', 'Horror', 'Music', 'Mystery', 'Romance', 'ScienceFiction', 'TVMovie', 'Thriller', 'War', 'Western']

#df = df[df['revenue'] != 0]
#X = df[relevant_col]
#y = df[['revenue']]
#X.drop(X.tail(1).index,inplace=True)
#y.drop(y.tail(1).index,inplace=True)

# %%
# Python3 program two find number of
# days between two given dates
 
# A date has day 'd', month 'm' and year 'y'
 
class Date:
    def __init__(self, m, d, y):
        self.d = d
        self.m = m
        self.y = y
 
 
# To store number of days in all months from
# January to Dec.
monthDays = [31, 28, 31, 30, 31, 30,
             31, 31, 30, 31, 30, 31]
 
# This function counts number of leap years
# before the given date
 
 
def countLeapYears(d):
 
    years = d.y
 
    # Check if the current year needs to be considered
    # for the count of leap years or not
    if (d.m <= 2):
        years -= 1
 
    # An year is a leap year if it is a multiple of 4,
    # multiple of 400 and not a multiple of 100.
    return int(years / 4) - int(years / 100) + int(years / 400)
 
 
# This function returns number of days between two
# given dates
def getDifference(dt1, dt2):
 
    # COUNT TOTAL NUMBER OF DAYS BEFORE FIRST DATE 'dt1'
 
    # initialize count using years and day
    n1 = dt1.y * 365 + dt1.d
 
    # Add days for months in given date
    for i in range(0, dt1.m - 1):
        n1 += monthDays[i]
 
    # Since every leap year is of 366 days,
    # Add a day for every leap year
    n1 += countLeapYears(dt1)
 
    # SIMILARLY, COUNT TOTAL NUMBER OF DAYS BEFORE 'dt2'
 
    n2 = dt2.y * 365 + dt2.d
    for i in range(0, dt2.m - 1):
        n2 += monthDays[i]
    n2 += countLeapYears(dt2)
 
    # return difference between two counts
    return (n2 - n1)
 

# Declare a list that is to be converted into a column
date_number = []

# Driver program
for item in df['release_date']:
  dt1 = Date(1,1,1900)
  date = str(item)
  date = date.split("/")
  dt2 = Date(int(date[0]),int(date[1]),int(date[2]))
  date_number.append(float(getDifference(dt1,dt2)))

# Using 'Address' as the column name
# and equating it to the list
df['date_number'] = date_number
del df['release_date']


relevant_col = ['date_number', 'popularity', 'reviews', 'reviews_average', 'budget', 'runtime', 'af', 'ar', 'bn', 'cn', 'cs', 'cy', 'da', 'de', 'el', 'en', 'es', 'fa', 'fr', 'he', 'hi', 'hu', 'id', 'is', 'it', 'ja', 'km', 'kn', 'ko', 'mk', 'ml', 'mn', 'mr', 'ms', 'nb', 'nl', 'no', 'pl', 'pt', 'ru', 'sh', 'si', 'sk', 'sl', 'sr', 'sv', 'ta', 'te', 'th', 'tl', 'tr', 'uk', 'ur', 'xx', 'zh', 'Action', 'Adventure', 'Animation', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy', 'History', 'Horror', 'Music', 'Mystery', 'Romance', 'ScienceFiction', 'TVMovie', 'Thriller', 'War', 'Western']
relevant_col2 = ['date_number', 'popularity', 'reviews', 'reviews_average', 'budget', 'runtime', 'af', 'ar', 'bn', 'cn', 'cs', 'cy', 'da', 'de', 'el', 'en', 'es', 'fa', 'fr', 'he', 'hi', 'hu', 'id', 'is', 'it', 'ja', 'km', 'kn', 'ko', 'mk', 'ml', 'mn', 'mr', 'ms', 'nb', 'nl', 'no', 'pl', 'pt', 'ru', 'sh', 'si', 'sk', 'sl', 'sr', 'sv', 'ta', 'te', 'th', 'tl', 'tr', 'uk', 'ur', 'xx', 'zh', 'Action', 'Adventure', 'Animation', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy', 'History', 'Music', 'Mystery', 'Romance', 'ScienceFiction', 'TVMovie', 'Thriller', 'War', 'Western']
relevant_col3 = ['budget','runtime']

#df_filtered = df[df['revenue'] != 0]
X = df[relevant_col]
y = df[['revenue']]
#X.drop(X.tail(1).index,inplace=True)
#y.drop(y.tail(1).index,inplace=True)

# %%
y = np.ravel(y)
print(y)
from sklearn.model_selection import train_test_split

import random
n1 = random.randint(0,100)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state=n1)
# Out:
# [       0.        0.        0. ...  1023510. 12017369.  5844868.]

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

import random
n2 = random.randint(0,100)

from sklearn.ensemble import GradientBoostingRegressor
pipe = make_pipeline(StandardScaler(), GradientBoostingRegressor()) # this "pipe" *first* scales the data, then trains the model
pipe.fit(X_train, y_train)  # apply scaling on training data # VERY IMPORTANT - we *fit* the model (train it) on the *training data*
pipe.score(X_test, y_test)  # but we test it on the *testing data*, which it hasn't seen before
# Out:
# 0.641578280986072

# %%
import pickle

pipe.fit(X,y)

pickle.dump(pipe, open('model.pkl', 'wb'))

# %%
pickled_model = pickle.load(open('model.pkl', 'rb'))
# Out:
# array([ 3.67561595e+05,  1.03832288e+06, -3.45530384e+05,  1.16131554e+08,
#         1.13642686e+06,  1.13642686e+06,  2.53058020e+05, -6.93782074e+03,
#         1.25093043e+06, -2.67325137e+05,  4.17119003e+07,  2.53058020e+05,
#         1.56886398e+06,  1.13642686e+06,  2.53058020e+05,  1.28603045e+07,
#         2.53058020e+05,  1.74852773e+05,  2.53058020e+05, -3.26933519e+05,
#         9.60523285e+05,  4.53969209e+07,  2.35412884e+06,  3.69461651e+06,
#         2.53058020e+05,  5.17939726e+05,  2.53058020e+05,  1.74852773e+05,
